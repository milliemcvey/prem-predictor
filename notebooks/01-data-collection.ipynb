# %%
import pandas as pd 
df = pd.read_csv("../data/cleaned/epl-dataset-clean.csv")

df.head()
# Out:
#     Season  Pos               Team  Pld     W     D     L    GF    GA  GD  \
# 0  2000-01    1  Manchester United   38  24.0   8.0   6.0  79.0  31.0  48
# 1  2000-01    2            Arsenal   38  20.0  10.0   8.0  63.0  38.0  25
# 2  2000-01    3          Liverpool   38  20.0   9.0   9.0  71.0  39.0  32
# 3  2000-01    4       Leeds United   38  20.0   8.0  10.0  64.0  43.0  21
# 4  2000-01    5       Ipswich Town   38  20.0   6.0  12.0  57.0  42.0  15
#
#    Pts Relegation
# 0   80         No
# 1   70         No
# 2   69         No
# 3   68         No
# 4   66         No
